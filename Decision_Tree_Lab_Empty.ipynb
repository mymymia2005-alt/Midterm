# %% [markdown]
# <a href="https://colab.research.google.com/github/mymymia2005-alt/Midterm/blob/main/Decision_Tree_Lab_Empty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
# <center><img src="data:image/png;base64,..." width=150 height=200/></center>
#
# <h1 style="color:#57068C;font-family:Helvetica,Arial,sans-serif;margin-bottom:0">DS4EVERYONE — DS-UA 9111</h1>
# <h3 style="color:#000;font-family:Helvetica,Arial,sans-serif;margin-top:4px">New York University</h3>
#
# <hr style="border:0;border-top:2px solid #57068C;width:60%">
#
# <h2 style="font-family:Helvetica,Arial,sans-serif;color:#222;margin-bottom:0">Session 10 — Decision Trees</h2>
# <h3 style="font-family:Helvetica,Arial,sans-serif;color:#444;margin-top:6px;font-weight:400">Lab · Explainable Decision Trees + W&B Tuning — Student Version</h3>
#
# <p style="font-family:Helvetica,Arial,sans-serif;font-size:14px;color:#555;margin-top:14px">
# Instructor: <b>Professor Gaëtan Brison ©</b><br>Bachelor — Final Year · Spring Semester
# </p>
#
# <span style="display:inline-block;padding:6px 14px;border-radius:14px;background:#A05CC9;color:#fff;font-family:Helvetica,Arial,sans-serif;font-size:12px;letter-spacing:1px">EXERCISES · STUDENT VERSION</span>
#
# </div>
#
# ---

# %% [markdown]
# ## 🧭 How to use this notebook
#
# Each exercise contains a short prompt, a code cell with **`# TODO:`** placeholders for you to fill in, and a follow-up explanation.
# **Do not** look at the solutions notebook until you have made a serious attempt yourself — productive struggle is how you build coding intuition.
#
# If a cell raises an exception, that is *information*, not failure. Read the message, hypothesize, fix, repeat.
#
# **This lab needs two free accounts/tools beyond the usual stack:**
#
# 1. **Graphviz** — the Python package *and* the system binary (`brew install graphviz` / `sudo apt-get install graphviz`). Colab has it pre-installed.
#
# 2. **Weights & Biases** — a free account at [wandb.ai](https://wandb.ai); copy your API key from [wandb.ai/authorize](https://wandb.ai/authorize) for the `wandb.login()` step.
#
# Work top-to-bottom: fill each **`# TODO`** / `...`, run the cell, then read the *After* note to check your understanding. The matching **Solutions** notebook has every answer — use it only after a genuine attempt.
#
# ---

# %% [markdown]
# ## 📖 Table of Contents
#
# - **Part 1** — [Setup & the Breast Cancer Dataset](#part-1)
# - **Part 2** — [Your First Decision Tree](#part-2)
# - **Part 3** — [Explaining the Tree with Graphviz](#part-3)
# - **Part 4** — [Gini Impurity vs Entropy](#part-4)
# - **Part 5** — [Feature Importance](#part-5)
# - **Part 6** — [Underfitting vs Overfitting — the Depth Curve](#part-6)
# - **Part 7** — [Hyperparameter Tuning with Weights & Biases](#part-7)
# - **Part 8** — [Final Held-out Evaluation](#part-8)
# - **Bonus** — [Bonus Questions](#bonus)
#
# ---

# %% [markdown]
# <a id='part-1'></a>
#
# ## Part 1 — Setup & the Breast Cancer Dataset
#
# A decision tree answers a question by walking an example from the **root** down a chain of yes/no **conditions** until it reaches a **leaf** that holds the prediction (see the lecture slides). We will build, *explain*, and *tune* one on the **Breast Cancer Wisconsin** dataset — the same data behind the `radius_mean` / `concave points_mean` scatter and tree in the slides. It ships with scikit-learn, so there is no CSV to download.

# %% [markdown]
# **📝 Before you run this cell**
#
# We import the scientific stack plus the three tools this lab is built around: scikit-learn (`DecisionTreeClassifier` + the tree exporters), **Graphviz** (to draw the tree), and later **Weights & Biases**. Uncomment the install line the first time you run this in a fresh environment.
#
# > **Heads-up on Graphviz.** The `graphviz` Python package is only a thin wrapper. To render images you also need the *system* Graphviz binary: `brew install graphviz` (macOS) or `sudo apt-get install graphviz` (Ubuntu). Google Colab already has it.

# %%
# Run once if needed (Colab already ships most of these):
# !pip install scikit-learn graphviz optuna wandb plotly --quiet

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# TODO: import the tools you will need
#   - load_breast_cancer                       from sklearn.datasets
#   - train_test_split, cross_val_score, StratifiedKFold   from sklearn.model_selection
#   - DecisionTreeClassifier, export_graphviz, export_text, plot_tree   from sklearn.tree
#   - metrics                                   from sklearn
#   - graphviz
...

from sklearn.datasets import load_breast_cancer

from sklearn.model_selection import (
    train_test_split,
    cross_val_score,
    StratifiedKFold
)

from sklearn.tree import (
    DecisionTreeClassifier,
    export_graphviz,
    export_text,
    plot_tree
)

from sklearn import metrics

import graphviz



NYU_PURPLE = "#57068C"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 3.8 MB/s eta 0:00:00

# %% [markdown]
# **🔎 After running the cell**
#
# If the import of `graphviz` fails, install the *system* binary (see the note above) and restart the kernel. Everything else is pure Python and pip-installable.

# %% [markdown]
# **📝 Before you run this cell**
#
# We load the dataset **as a DataFrame** (`as_frame=True`) so feature names survive — they are what makes the tree readable later. There are 569 patients, 30 numerical features, and a binary target: **0 = malignant, 1 = benign**.

# %%
# TODO: load the Breast Cancer Wisconsin dataset as a DataFrame (as_frame=True)
data = load_breast_cancer(as_frame=True)

X = data.data                 # the 30 features
y = data.target               # the 0/1 target
class_names = list(data.target_names)  # data.target_names as a list

print(f"Shape          : {X.shape}")
print(f"Target classes : {class_names}")
X.head()
# Out:
# Shape          : (569, 30)
# Target classes : [np.str_('malignant'), np.str_('benign')]
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %% [markdown]
# **🔎 After running the cell**
#
# We have **357 benign vs. 212 malignant** — mildly imbalanced. That is why we will use `StratifiedKFold` later: it preserves this ratio inside every cross-validation fold so no fold accidentally sees almost no malignant cases.

# %% [markdown]
# **📝 Before you run this cell**
#
# Before any modelling, reproduce the **“Breast Cancer dataset in 2D”** scatter from the slides: `mean radius` on x, `mean concave points` on y, coloured by diagnosis. This is the intuition for *why* a tree of axis-aligned splits can separate the two classes.

# %%
# TODO: scatter 'mean radius' (x) vs 'mean concave points' (y), one colour per diagnosis
fig, ax = plt.subplots(figsize=(7, 5))

for target_value, diagnosis in enumerate(class_names):
    mask = y == target_value
    ax.scatter(
        X.loc[mask, "mean radius"],
        X.loc[mask, "mean concave points"],
        label=diagnosis,
        alpha=0.7
    )

ax.set_xlabel("mean radius")
ax.set_ylabel("mean concave points")
ax.set_title("Breast Cancer dataset in 2D")
ax.legend(title="diagnosis")
plt.show()

# %% [markdown]
# **🔎 After running the cell**
#
# Malignant tumours (blue triangles) sit toward **larger radius and more concave points**; benign tumours (red squares) cluster near the origin. The classes overlap, so no single straight cut is perfect — but a few axis-aligned splits get us most of the way. That is exactly what a decision tree learns.

# %% [markdown]
# <a id='part-2'></a>
#
# ## Part 2 — Your First Decision Tree
#
# Time to grow our first tree. We hold out a test set, fit a deliberately **shallow** tree (`max_depth=2`), and measure accuracy — reproducing the ~0.90 result from the slides.

# %% [markdown]
# **📝 Before you run this cell**
#
# Split into **80% train / 20% test**, stratified on `y` so both sets keep the 357:212 class ratio. `random_state=1` makes the split reproducible — you and your neighbour get identical rows.

# %%
# TODO: stratified 80/20 split with random_state=1
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = 0.8, random_state = 1)
print(f"Train: {X_train.shape[0]} rows | Test: {X_test.shape[0]} rows")
# Out:
# Train: 455 rows | Test: 114 rows

# %% [markdown]
# **🔎 After running the cell**
#
# 455 training rows, 114 test rows. The test set is now **locked away** — we only touch it once, at the very end, after tuning is finished.

# %% [markdown]
# **📝 Before you run this cell**
#
# Fit a `DecisionTreeClassifier` capped at `max_depth=2`. A shallow tree is the whole point here: it is the most *human-readable* model in machine learning, which is what makes the Graphviz explanation in Part 3 meaningful.

# %%
# TODO: instantiate DecisionTreeClassifier(max_depth=2, random_state=1), fit, predict
dt = DecisionTreeClassifier(max_depth=2, random_state=1)

dt.fit(X_train, y_train)

y_pred = dt.predict(X_test)

acc = metrics.accuracy_score(y_test, y_pred)
print(f"Test accuracy (max_depth=2): {acc:.4f}")
# Out:
# Test accuracy (max_depth=2): 0.8860

# %% [markdown]
# **🔎 After running the cell**
#
# A two-question tree already classifies ~90% of unseen tumours correctly — the same ballpark as the slides. Two well-chosen splits do most of the work; the rest of this lab is about *understanding* and *improving* this model.

# %% [markdown]
# <a id='part-3'></a>
#
# ## Part 3 — Explaining the Tree with Graphviz
#
# A decision tree is a **white-box** model: you can read exactly why it made any prediction. We render the fitted tree three complementary ways — **Graphviz** (the prettiest), `plot_tree` (no system binary needed), and `export_text` (diff-friendly rules).

# %% [markdown]
# **📝 Before you run this cell**
#
# `export_graphviz` turns the fitted tree into a **DOT** string; `graphviz.Source` renders it inline. `filled=True` colours each node by its majority class and `rounded=True` softens the boxes — this is the chart you put on a slide.

# %%
# TODO: build the DOT string with export_graphviz, then render it with graphviz.Source
#   pass: the fitted tree, out_file=None, feature_names, class_names,
#         filled=True, rounded=True, special_characters=True
dot_data = export_graphviz(
    dt,
    out_file=None,
    feature_names=X.columns,
    class_names=class_names,
    filled=True,
    rounded=True,
    special_characters=True
)

graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# **🔎 After running the cell**
#
# Read it top-down. The **root** splits on `mean concave points` (or a closely related feature) — the dominant signal we saw in the 2D scatter. Each box shows the split rule, the `gini` impurity, `samples` reaching the node, the class `value` counts, and the predicted `class`. Darker fill = purer node. This *is* the model — no approximation.

# %% [markdown]
# **📝 Before you run this cell**
#
# If the system Graphviz binary is unavailable, scikit-learn's own `plot_tree` draws the same tree with matplotlib — zero extra dependencies. Handy on locked-down machines.

# %%
# TODO: draw the same tree with sklearn's plot_tree (feature_names, class_names, filled=True)
fig, ax = plt.subplots(figsize=(14, 7))

plot_tree(
    dt,
    feature_names=X.columns,
    class_names=class_names,
    filled=True,
    ax=ax
)

plt.show()

# %% [markdown]
# **🔎 After running the cell**
#
# Same structure, matplotlib styling. Use Graphviz for polished reports and `plot_tree` for a quick look or when you cannot install the binary.

# %% [markdown]
# **📝 Before you run this cell**
#
# `export_text` prints the tree as an indented **rule set** — plain text, so it diffs cleanly in Git and pastes into documentation.

# %%
# TODO: print the tree as text rules with export_text(dt, feature_names=...)
rules = export_text(
    dt,
    feature_names=list(X.columns)
)

print(rules)
# Out:
# |--- worst perimeter <= 106.05
# |   |--- worst concave points <= 0.16
# |   |   |--- class: 1
# |   |--- worst concave points >  0.16
# |   |   |--- class: 0
# |--- worst perimeter >  106.05
# |   |--- worst texture <= 20.65
# |   |   |--- class: 1
# |   |--- worst texture >  20.65
# |   |   |--- class: 0

# %% [markdown]
# **🔎 After running the cell**
#
# Each indented block is one branch: *“if concave points ≤ t and radius ≤ s → predict benign”*. Because the rules are exact, a clinician could audit them by hand — the property that makes shallow trees a favourite in regulated, high-stakes settings.

# %% [markdown]
# <a id='part-4'></a>
#
# ## Part 4 — Gini Impurity vs Entropy
#
# How does the tree *choose* each split? It picks the condition that makes the child nodes as **pure** as possible. Two ways to measure (im)purity: **Gini impurity** and **entropy**.

# %% [markdown]
# Picture a jar of multi-coloured marbles and you want each child jar to hold mostly one colour:
#
# - **Gini impurity** is a *messiness score*. One colour only → Gini = 0 (not messy). An even mix → Gini is high. Formally `Gini = 1 - Σ pᵢ²`.
# - **Entropy** is a *surprise score*. Pull a marble from a single-colour jar → no surprise → entropy = 0. An even mix → maximum surprise. Formally `Entropy = - Σ pᵢ log₂ pᵢ`.
#
# At every node the tree tries candidate splits and keeps the one that **reduces** impurity the most (the *information gain*). Both metrics are minimised by pure nodes, so they usually pick very similar trees.

# %% [markdown]
# **📝 Before you run this cell**
#
# Train the same shallow tree with each criterion and compare test accuracy. On most datasets the difference is tiny — verify that for yourself.

# %%
# TODO: loop over ['gini', 'entropy'], fit a depth-2 tree with each, print test accuracy
for criterion in ["gini", "entropy"]:
    model = DecisionTreeClassifier(
        criterion=criterion,
        max_depth=2,
        random_state=1
    )

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    acc = metrics.accuracy_score(y_test, y_pred)
    print(f"{criterion:7s} test accuracy: {acc:.4f}")
# Out:
# gini    test accuracy: 0.8860
# entropy test accuracy: 0.8684

# %% [markdown]
# **🔎 After running the cell**
#
# Gini and entropy land within a hair of each other. Gini is the scikit-learn default because it skips the logarithm and is marginally cheaper to compute; entropy can occasionally produce a slightly more balanced tree. In practice, tune *other* hyperparameters first.

# %% [markdown]
# **📝 Before you run this cell**
#
# Let's compute the Gini impurity of the **root** node by hand so the formula is no longer a black box: `Gini = 1 - Σ pᵢ²`, where `pᵢ` is the proportion of class *i*.

# %%
# TODO: p = class proportions in y_train (value_counts(normalize=True))
#       gini_root = 1 - sum of p squared
p = y_train.value_counts(normalize=True)

gini_root = 1 - (p ** 2).sum()

print(f"Gini impurity at the root: {gini_root:.4f}")
# Out:
# Gini impurity at the root: 0.4681

# %% [markdown]
# **🔎 After running the cell**
#
# The root impurity (~0.47) is close to the 0.5 ceiling because the classes are fairly mixed before any split. Compare this number with the `gini` printed in the **root box** of your Graphviz chart — they match. Every split the tree makes drives this number down.

# %% [markdown]
# <a id='part-5'></a>
#
# ## Part 5 — Feature Importance
#
# Which of the 30 features does the tree actually rely on? `feature_importances_` answers that — the same diagnostic the slides' Lab 06 asks you to plot.

# %% [markdown]
# **📝 Before you run this cell**
#
# `feature_importances_` measures, per feature, the total **reduction in Gini** it contributes across every split where it is used, weighted by how many samples reach that split. We sort and plot the top 10.

# %%
# TODO: build a DataFrame of (feature, importance) from dt.feature_importances_,
#       sort descending, take head(10), and draw a horizontal bar chart
importances = dt.feature_importances_

fi = (
    pd.DataFrame({
        "feature": X.columns,
        "importance": importances
    })
    .sort_values("importance", ascending=False)
    .head(10)
)

fig, ax = plt.subplots(figsize=(8, 5))

ax.barh(fi["feature"], fi["importance"])
ax.invert_yaxis()
ax.set_xlabel("importance")
ax.set_title("Top 10 feature importances")

plt.show()

# %% [markdown]
# **🔎 After running the cell**
#
# Because the tree is only two levels deep, **just two or three features carry all the importance** (the others are exactly 0 — the tree never split on them). Note the caveat for later in your career: impurity-based importance is **biased toward high-cardinality / continuous features**; permutation importance (Bonus 4) is a fairer, model-agnostic alternative.

# %% [markdown]
# <a id='part-6'></a>
#
# ## Part 6 — Underfitting vs Overfitting — the Depth Curve
#
# The slides warn: *simple trees underfit, complex trees overfit*. We make that concrete by sweeping `max_depth` from 1 to 15 and plotting **train vs test accuracy** — the single most important diagnostic for trees.

# %% [markdown]
# **📝 Before you run this cell**
#
# For each depth, fit a tree and record train and test accuracy. Watch the two curves diverge as the tree is allowed to grow.

# %%
# TODO: for d in range(1, 16): fit a tree, store clf.score on train AND test
#       then plot both curves vs depth and report the depth with the best test score
depths = range(1, 16)
train_acc, test_acc = [], []

for d in depths:
    clf = DecisionTreeClassifier(max_depth=d, random_state=1)
    clf.fit(X_train, y_train)

    train_acc.append(clf.score(X_train, y_train))
    test_acc.append(clf.score(X_test, y_test))

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(depths, train_acc, marker="o", label="train")
ax.plot(depths, test_acc, marker="o", label="test")

ax.set_xlabel("max_depth")
ax.set_ylabel("accuracy")
ax.set_title("Decision tree accuracy vs max_depth")
ax.legend()

plt.show()

best_depth = depths[test_acc.index(max(test_acc))]
print(f"Highest test accuracy at max_depth = {best_depth}")
# Out:
# Highest test accuracy at max_depth = 4

# %% [markdown]
# **🔎 After running the cell**
#
# Classic shape: **train accuracy marches to 1.0** (a deep enough tree memorises the training set) while **test accuracy peaks early and then sags** — that gap is overfitting / high variance. The sweet spot is shallow. This curve is precisely why we tune `max_depth` rather than leaving it unbounded.

# %% [markdown]
# <a id='part-7'></a>
#
# ## Part 7 — Hyperparameter Tuning with Weights & Biases
#
# Eyeballing one curve only tunes one knob. Now we search several hyperparameters at once and log **every configuration to [Weights & Biases](https://wandb.ai)** so the whole sweep becomes an interactive, shareable dashboard.

# %% [markdown]
# **📝 Before you run this cell**
#
# First, **log in to W&B**. You need a free account — grab your key from [wandb.ai/authorize](https://wandb.ai/authorize). In Colab/Jupyter this opens an input box; on a local machine the key is saved to `~/.netrc` so you only do this once.

# %%
import wandb

# TODO: authenticate with Weights & Biases (one line).
#       Get your key from https://wandb.ai/authorize
wandb.login()
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 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
# wandb: WARNING Invalid choice
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter: ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: mc9483 (models-new-york-university1810) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# **🔎 After running the cell**
#
# A successful login prints your username. If you just want to experiment without an account, run `wandb.login(anonymous='allow')` or set the env var `WANDB_MODE=offline` to log to disk only.

# %% [markdown]
# **📝 Before you run this cell**
#
# We sweep a small, readable grid over the three knobs that matter most for a tree: `max_depth`, `criterion`, and `min_samples_leaf`. For each combination we score it with **5-fold cross-validation on the training set** (never the test set) and open one **W&B run** per configuration — they all land in the same project dashboard.

# %%
import itertools

param_grid = {
    "max_depth":        [2, 3, 5, 8, None],
    "criterion":        ["gini", "entropy"],
    "min_samples_leaf": [1, 5, 20],
}
keys = list(param_grid)
combos = list(itertools.product(*param_grid.values()))
print(f"{len(combos)} configurations to evaluate")

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)
WB_PROJECT = "ds4e-decision-tree"
results = []

for values in combos:
    params = dict(zip(keys, values))

    clf = DecisionTreeClassifier(**params, random_state=1)

    scores = cross_val_score(
        clf,
        X_train,
        y_train,
        cv=cv,
        scoring="accuracy"
    )

    run = wandb.init(
        project=WB_PROJECT,
        config=params,
        name=f"depth={params['max_depth']}_criterion={params['criterion']}_leaf={params['min_samples_leaf']}",
        reinit=True
    )

    wandb.log({
        "cv_accuracy": scores.mean(),
        "cv_std": scores.std()
    })

    wandb.finish()

    results.append({
        **params,
        "cv_accuracy": scores.mean(),
        "cv_std": scores.std()
    })

results_df = pd.DataFrame(results).sort_values("cv_accuracy", ascending=False)
results_df.head(10)
# Out:
# 30 configurations to evaluate
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130226-0v9nl2mz</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/0v9nl2mz' target="_blank">depth=2_criterion=gini_leaf=1</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/0v9nl2mz' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/0v9nl2mz</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92747</td></tr><tr><td>cv_std</td><td>0.0323</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=2_criterion=gini_leaf=1</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/0v9nl2mz' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/0v9nl2mz</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130226-0v9nl2mz/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130229-y5oqro0q</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/y5oqro0q' target="_blank">depth=2_criterion=gini_leaf=5</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/y5oqro0q' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/y5oqro0q</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92527</td></tr><tr><td>cv_std</td><td>0.03139</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=2_criterion=gini_leaf=5</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/y5oqro0q' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/y5oqro0q</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130229-y5oqro0q/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130231-ta9p77qo</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ta9p77qo' target="_blank">depth=2_criterion=gini_leaf=20</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ta9p77qo' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ta9p77qo</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92088</td></tr><tr><td>cv_std</td><td>0.02637</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=2_criterion=gini_leaf=20</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ta9p77qo' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ta9p77qo</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130231-ta9p77qo/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130233-g0481d8g</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/g0481d8g' target="_blank">depth=2_criterion=entropy_leaf=1</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/g0481d8g' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/g0481d8g</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.90989</td></tr><tr><td>cv_std</td><td>0.01077</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=2_criterion=entropy_leaf=1</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/g0481d8g' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/g0481d8g</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130233-g0481d8g/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130236-nihggysq</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/nihggysq' target="_blank">depth=2_criterion=entropy_leaf=5</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/nihggysq' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/nihggysq</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.90989</td></tr><tr><td>cv_std</td><td>0.01077</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=2_criterion=entropy_leaf=5</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/nihggysq' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/nihggysq</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130236-nihggysq/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130239-ckdevas6</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ckdevas6' target="_blank">depth=2_criterion=entropy_leaf=20</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ckdevas6' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ckdevas6</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.91429</td></tr><tr><td>cv_std</td><td>0.01458</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=2_criterion=entropy_leaf=20</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ckdevas6' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ckdevas6</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130239-ckdevas6/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130241-9t460csx</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/9t460csx' target="_blank">depth=3_criterion=gini_leaf=1</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/9t460csx' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/9t460csx</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.91209</td></tr><tr><td>cv_std</td><td>0.0326</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=3_criterion=gini_leaf=1</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/9t460csx' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/9t460csx</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130241-9t460csx/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130244-zdsfmcco</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/zdsfmcco' target="_blank">depth=3_criterion=gini_leaf=5</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/zdsfmcco' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/zdsfmcco</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.91648</td></tr><tr><td>cv_std</td><td>0.03154</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=3_criterion=gini_leaf=5</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/zdsfmcco' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/zdsfmcco</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130244-zdsfmcco/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130246-xwcv4pls</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/xwcv4pls' target="_blank">depth=3_criterion=gini_leaf=20</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/xwcv4pls' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/xwcv4pls</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92967</td></tr><tr><td>cv_std</td><td>0.02563</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=3_criterion=gini_leaf=20</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/xwcv4pls' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/xwcv4pls</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130246-xwcv4pls/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130249-q41gj3db</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/q41gj3db' target="_blank">depth=3_criterion=entropy_leaf=1</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/q41gj3db' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/q41gj3db</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92527</td></tr><tr><td>cv_std</td><td>0.02727</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=3_criterion=entropy_leaf=1</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/q41gj3db' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/q41gj3db</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130249-q41gj3db/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130251-fn6646v5</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/fn6646v5' target="_blank">depth=3_criterion=entropy_leaf=5</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/fn6646v5' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/fn6646v5</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92967</td></tr><tr><td>cv_std</td><td>0.02563</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=3_criterion=entropy_leaf=5</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/fn6646v5' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/fn6646v5</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130251-fn6646v5/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130253-1q6kfl4r</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/1q6kfl4r' target="_blank">depth=3_criterion=entropy_leaf=20</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/1q6kfl4r' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/1q6kfl4r</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.93846</td></tr><tr><td>cv_std</td><td>0.02563</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=3_criterion=entropy_leaf=20</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/1q6kfl4r' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/1q6kfl4r</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130253-1q6kfl4r/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130256-462rv5sh</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/462rv5sh' target="_blank">depth=5_criterion=gini_leaf=1</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/462rv5sh' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/462rv5sh</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.91868</td></tr><tr><td>cv_std</td><td>0.02916</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=5_criterion=gini_leaf=1</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/462rv5sh' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/462rv5sh</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130256-462rv5sh/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130258-f2ww6j4c</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/f2ww6j4c' target="_blank">depth=5_criterion=gini_leaf=5</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/f2ww6j4c' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/f2ww6j4c</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92088</td></tr><tr><td>cv_std</td><td>0.03289</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=5_criterion=gini_leaf=5</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/f2ww6j4c' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/f2ww6j4c</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130258-f2ww6j4c/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130300-29v74gfm</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/29v74gfm' target="_blank">depth=5_criterion=gini_leaf=20</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/29v74gfm' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/29v74gfm</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92967</td></tr><tr><td>cv_std</td><td>0.02563</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=5_criterion=gini_leaf=20</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/29v74gfm' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/29v74gfm</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130300-29v74gfm/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130303-1qs96jah</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/1qs96jah' target="_blank">depth=5_criterion=entropy_leaf=1</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/1qs96jah' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/1qs96jah</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92527</td></tr><tr><td>cv_std</td><td>0.01758</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=5_criterion=entropy_leaf=1</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/1qs96jah' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/1qs96jah</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130303-1qs96jah/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130305-rgezobo8</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/rgezobo8' target="_blank">depth=5_criterion=entropy_leaf=5</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/rgezobo8' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/rgezobo8</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.93407</td></tr><tr><td>cv_std</td><td>0.02305</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=5_criterion=entropy_leaf=5</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/rgezobo8' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/rgezobo8</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130305-rgezobo8/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130307-8xc41j7l</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/8xc41j7l' target="_blank">depth=5_criterion=entropy_leaf=20</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/8xc41j7l' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/8xc41j7l</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.93846</td></tr><tr><td>cv_std</td><td>0.02563</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=5_criterion=entropy_leaf=20</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/8xc41j7l' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/8xc41j7l</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130307-8xc41j7l/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130309-aii79y5a</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/aii79y5a' target="_blank">depth=8_criterion=gini_leaf=1</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/aii79y5a' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/aii79y5a</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92088</td></tr><tr><td>cv_std</td><td>0.02544</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=8_criterion=gini_leaf=1</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/aii79y5a' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/aii79y5a</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130309-aii79y5a/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130312-yxaywz56</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/yxaywz56' target="_blank">depth=8_criterion=gini_leaf=5</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/yxaywz56' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/yxaywz56</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92088</td></tr><tr><td>cv_std</td><td>0.03289</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=8_criterion=gini_leaf=5</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/yxaywz56' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/yxaywz56</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130312-yxaywz56/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130314-ejxev7j6</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ejxev7j6' target="_blank">depth=8_criterion=gini_leaf=20</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ejxev7j6' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ejxev7j6</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92967</td></tr><tr><td>cv_std</td><td>0.02563</td></tr></table><br/></div></div>
# ...
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.93846</td></tr><tr><td>cv_std</td><td>0.02563</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=8_criterion=entropy_leaf=20</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/pbax550p' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/pbax550p</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130321-pbax550p/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130324-mp0j7y8i</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/mp0j7y8i' target="_blank">depth=None_criterion=gini_leaf=1</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/mp0j7y8i' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/mp0j7y8i</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92088</td></tr><tr><td>cv_std</td><td>0.02544</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=None_criterion=gini_leaf=1</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/mp0j7y8i' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/mp0j7y8i</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130324-mp0j7y8i/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130327-qhgqpnsa</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/qhgqpnsa' target="_blank">depth=None_criterion=gini_leaf=5</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/qhgqpnsa' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/qhgqpnsa</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92088</td></tr><tr><td>cv_std</td><td>0.03289</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=None_criterion=gini_leaf=5</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/qhgqpnsa' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/qhgqpnsa</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130327-qhgqpnsa/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130329-2l1thn4m</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/2l1thn4m' target="_blank">depth=None_criterion=gini_leaf=20</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/2l1thn4m' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/2l1thn4m</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.92967</td></tr><tr><td>cv_std</td><td>0.02563</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=None_criterion=gini_leaf=20</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/2l1thn4m' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/2l1thn4m</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130329-2l1thn4m/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130331-hez7uw7d</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/hez7uw7d' target="_blank">depth=None_criterion=entropy_leaf=1</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/hez7uw7d' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/hez7uw7d</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.93187</td></tr><tr><td>cv_std</td><td>0.01758</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=None_criterion=entropy_leaf=1</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/hez7uw7d' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/hez7uw7d</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130331-hez7uw7d/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130334-ohgxwuqw</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ohgxwuqw' target="_blank">depth=None_criterion=entropy_leaf=5</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ohgxwuqw' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ohgxwuqw</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.93407</td></tr><tr><td>cv_std</td><td>0.02305</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=None_criterion=entropy_leaf=5</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ohgxwuqw' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/ohgxwuqw</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130334-ohgxwuqw/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130336-f1mmbq4d</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/f1mmbq4d' target="_blank">depth=None_criterion=entropy_leaf=20</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/f1mmbq4d' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/f1mmbq4d</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>▁</td></tr><tr><td>cv_std</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_accuracy</td><td>0.93846</td></tr><tr><td>cv_std</td><td>0.02563</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">depth=None_criterion=entropy_leaf=20</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/f1mmbq4d' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/f1mmbq4d</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130336-f1mmbq4d/logs</code>
#     max_depth criterion  min_samples_leaf  cv_accuracy    cv_std
# 11        3.0   entropy                20     0.938462  0.025631
# 17        5.0   entropy                20     0.938462  0.025631
# 23        8.0   entropy                20     0.938462  0.025631
# 29        NaN   entropy                20     0.938462  0.025631
# 16        5.0   entropy                 5     0.934066  0.023051
# 22        8.0   entropy                 5     0.934066  0.023051
# 28        NaN   entropy                 5     0.934066  0.023051
# 21        8.0   entropy                 1     0.931868  0.017582
# 27        NaN   entropy                 1     0.931868  0.017582
# 8         3.0      gini                20     0.929670  0.025631

# %% [markdown]
# **🔎 After running the cell**
#
# Thirty runs now populate your **ds4e-decision-tree** project. Open the dashboard: the **parallel-coordinates** and **scatter** panels let you see at a glance which depth and leaf size win. We logged *cross-validated* accuracy — logging test accuracy for every config would be data leakage (Bonus 5).

# %% [markdown]
# **📝 Before you run this cell**
#
# Pick the winning configuration straight from the results list (we keep the raw Python values so `None` for `max_depth` survives instead of turning into `NaN` in the table).

# %%
# TODO: select the dict in `results` with the highest 'cv_accuracy'
best = max(results, key=lambda x: x["cv_accuracy"])

best_params = {
    k: best[k]
    for k in ("max_depth", "criterion", "min_samples_leaf")
}

print(f"Best configuration : {best_params}")
print(f"Best CV accuracy   : {best['cv_accuracy']:.4f} ± {best['cv_std']:.4f}")
# Out:
# Best configuration : {'max_depth': 3, 'criterion': 'entropy', 'min_samples_leaf': 20}
# Best CV accuracy   : 0.9385 ± 0.0256

# %% [markdown]
# **🔎 After running the cell**
#
# The cross-validated winner is typically a **moderate depth with a larger `min_samples_leaf`** — the regularising effect of bigger leaves beats an unbounded tree, exactly as the depth curve predicted. These are the hyperparameters we now lock in for the final model.

# %% [markdown]
# <a id='part-8'></a>
#
# ## Part 8 — Final Held-out Evaluation
#
# Tuning is done. We refit **one** model with the best hyperparameters on the full training set, then score it **once** on the held-out test set. After this point we do not touch the test set again — peeking and re-tuning would invalidate the number.

# %% [markdown]
# **📝 Before you run this cell**
#
# Refit with `best_params`, predict on the test set, and print accuracy plus a full `classification_report` (precision / recall / F1 per class — important on imbalanced medical data, where missing a malignant case is the costly error).

# %%
# TODO: refit a DecisionTreeClassifier(**best_params, random_state=1) on the full train set,
#       predict on X_test, print accuracy and classification_report
final_tree = DecisionTreeClassifier(**best_params, random_state=1)

final_tree.fit(X_train, y_train)

y_pred = final_tree.predict(X_test)

acc = metrics.accuracy_score(y_test, y_pred)
print(f"Test accuracy: {acc:.4f}")
print(metrics.classification_report(y_test, y_pred, target_names=class_names))
# Out:
# Test accuracy: 0.8860
#               precision    recall  f1-score   support
#
#    malignant       0.89      0.79      0.84        42
#       benign       0.88      0.94      0.91        72
#
#     accuracy                           0.89       114
#    macro avg       0.89      0.87      0.87       114
# weighted avg       0.89      0.89      0.88       114

# %% [markdown]
# **🔎 After running the cell**
#
# Compare the test accuracy with the cross-validated score from Part 7 — they should be close. A big gap (CV high, test low) would mean we over-tuned to the CV folds, a real risk on small datasets. Watch the **recall for `malignant`**: that is the share of cancers we correctly flag.

# %% [markdown]
# **📝 Before you run this cell**
#
# A confusion matrix shows *where* the errors fall — in particular how many malignant tumours were missed (false negatives, bottom-left).

# %%
# TODO: compute the confusion matrix and display it with ConfusionMatrixDisplay
cm = metrics.confusion_matrix(y_test, y_pred)

disp = metrics.ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=class_names
)

disp.plot()
plt.show()

# %% [markdown]
# **🔎 After running the cell**
#
# Off-diagonal cells are mistakes. In a clinical setting the **bottom-left** cell (malignant predicted benign) is the dangerous one; you would tune the decision threshold or class weights to shrink it even at the cost of a few extra false alarms.

# %% [markdown]
# **📝 Before you run this cell**
#
# Finally, **explain the tuned model the same way we explained the first one** — render it with Graphviz. This closes the loop: a model that is both *tuned* and *transparent*.

# %%
# TODO: render the FINAL tuned tree with export_graphviz + graphviz.Source
dot_data = export_graphviz(
    final_tree,
    out_file=None,
    feature_names=X.columns,
    class_names=class_names,
    filled=True,
    rounded=True,
    special_characters=True
)

graphviz.Source(dot_data)

# %% [markdown]
# **🔎 After running the cell**
#
# The tuned tree is deeper than the depth-2 starter, so it captures more structure — but each path is still a readable chain of conditions. That combination of accuracy *and* explainability is exactly why decision trees (and their ensembles) remain a first-choice model for tabular data.

# %% [markdown]
# **📝 Before you run this cell**
#
# Optional but satisfying: log the final model's test accuracy back to W&B as a dedicated run so your dashboard tells the full story — login, sweep, and the chosen model side by side.

# %%
# TODO: open a final wandb run named 'final-tuned-tree' with config=best_params,
#       log the test accuracy, then wandb.finish()

run = wandb.init(
    project=WB_PROJECT,
    name="final-tuned-tree",
    config=best_params,
    reinit=True
)

wandb.log({
    "test_accuracy": metrics.accuracy_score(y_test, y_pred)
})

wandb.finish()
# Out:
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260621_130546-rgd2beue</code>
# Syncing run <strong><a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/rgd2beue' target="_blank">final-tuned-tree</a></strong> to <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a>
#  View run at <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/rgd2beue' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/rgd2beue</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_accuracy</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_accuracy</td><td>0.88596</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">final-tuned-tree</strong> at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/rgd2beue' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree/runs/rgd2beue</a><br> View project at: <a href='https://wandb.ai/models-new-york-university1810/ds4e-decision-tree' target="_blank">https://wandb.ai/models-new-york-university1810/ds4e-decision-tree</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260621_130546-rgd2beue/logs</code>

# %% [markdown]
# **🔎 After running the cell**
#
# Your W&B project now contains the whole experiment trail: 30 sweep runs plus the final model. That reproducible, shareable record — not a screenshot of one number — is what separates a tidy ML workflow from an ad-hoc one.

# %% [markdown]
# <a id='bonus'></a>
#
# ---
#
# ## ✨ Bonus Questions
#
# These questions are optional but **highly encouraged**. They go slightly beyond the core material and are great talking points for technical interviews.
#
#
# **Bonus 1.** The slides note that decision trees **don't require feature scaling**. Explain why a tree is invariant to any *monotonic* rescaling of a single feature (e.g. multiplying `mean radius` by 1000), whereas KNN and logistic regression are not.
#
# **Bonus 2.** Gini and entropy almost always pick the same tree. Show that both equal 0 for a pure node and are maximised for a 50/50 split, then give one practical reason scikit-learn defaults to Gini.
#
# **Bonus 3.** Your depth curve showed train accuracy → 1.0 while test accuracy plateaued. Frame this with the **bias–variance** trade-off, and name the difference between **pre-pruning** (e.g. `max_depth`, `min_samples_leaf`) and **post-pruning** (`ccp_alpha` cost-complexity pruning).
#
# **Bonus 4.** `feature_importances_` is biased toward high-cardinality / continuous features. Describe **permutation importance** and explain why shuffling a feature on held-out data gives a fairer, model-agnostic importance score.
#
# **Bonus 5.** In the W&B sweep we logged **cross-validated** accuracy, not test accuracy. Why would logging the test score for every one of the 30 configurations be a form of data leakage, and what is the correct train / validation / test protocol?

# %% [markdown]
# ---
#
# <div align="center" style="font-family:Helvetica,Arial,sans-serif;color:#555;font-size:13px;margin-top:30px">
#
# ✅ <b>Don’t forget to push your work to GitHub.</b><br><br>
#
# <hr style="border:0;border-top:1px solid #57068C;width:50%">
#
# <b>DS4EVERYONE — DS-UA 9111</b> · New York University<br>
# Session 10 — Decision Trees<br>
# © Professor Gaëtan Brison © — All rights reserved.
#
# </div>
